# %%
# !pip install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.12)

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input, Concatenate, GlobalAveragePooling2D
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import pickle5 as pickle
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow as tf
seed=2022
tf.random.set_seed(seed)
np.random.seed(seed)

# %% [markdown]
# # mfcc

# %%
with open("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/1:1/mfcc_1565.pickle", "rb") as f:
    data = pickle.load(f)
length=[]
for i in range(len(data)):
    length.append(data[i].shape[1])
    
min_len=min(length)

result=[]
for i in range(len(data)):
    result.append(data[i][:,:min_len])
    
result_data=np.array(result)
result_data.shape
# Out:
# (2304, 30, 901)

# %% [markdown]
# # codiv-19, feature

# %%
with open("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/1:1/Y_data.pickle", "rb") as f:
    y = pickle.load(f)
features = pd.DataFrame(y)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    result_data, features, stratify = features, test_size = 0.2
)

# %%
features_train = Y_train.iloc[:,:-1].values
y_data_train = Y_train.iloc[:,-1].values

# %%
features_test = Y_test.iloc[:,:-1].values
y_data_test = Y_test.iloc[:,-1].values

# %%
# 각 입력에 대한 형태를 명시
img_input = Input(shape = (30,901,1), name = "features_train")
form_input = Input(shape = (3,), name = "y_data_train")

# %%
# 이미지 입력
x_1 = Conv2D(32, (3,3), activation = "relu")(img_input)
x_1 = Conv2D(32, (3,3), activation = "relu")(x_1)
x_1 = MaxPooling2D(strides = 2)(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = Conv2D(16, (3,3), activation='relu')(x_1)
x_1 = Conv2D(16, (3,3), activation='relu')(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = GlobalAveragePooling2D()(x_1)
x_1 = Flatten()(x_1)

# 피쳐 입력
# x_2 = Dense(128, input_dim = 3 ,activation  = "relu")(form_input)
x_2 = Dense(8, activation = "relu")(form_input)

x = Concatenate()([x_1, x_2])
rate_pred = Dense(1, name = "covid", activation = "sigmoid")(x)

# %%
model = Model(inputs = [img_input, form_input],
              outputs = [rate_pred])

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  features_train (InputLayer)    [(None, 30, 901, 1)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 28, 899, 32)  320         ['features_train[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 26, 897, 32)  9248        ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 13, 448, 32)  0           ['conv2d_1[0][0]']
#
#  dropout (Dropout)              (None, 13, 448, 32)  0           ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 11, 446, 16)  4624        ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 9, 444, 16)   2320        ['conv2d_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 9, 444, 16)   0           ['conv2d_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 16)          0           ['dropout_1[0][0]']
#  alAveragePooling2D)
#
#  y_data_train (InputLayer)      [(None, 3)]          0           []
#
#  flatten (Flatten)              (None, 16)           0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 8)            32          ['y_data_train[0][0]']
#
#  concatenate (Concatenate)      (None, 24)           0           ['flatten[0][0]',
#                                                                   'dense[0][0]']
#
#  covid (Dense)                  (None, 1)            25          ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 16,569
# Trainable params: 16,569
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import Nadam
nadam = Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

# %%
model.compile(optimizer = nadam,
              loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
model_path = "functional-first.h5"
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1, monitor = "val_accuracy")
es = EarlyStopping(patience=10, monitor = "val_accuracy")

# %%
hist = model.fit([X_train, features_train] , y_data_train,
                 epochs = 100, batch_size = 200,
                 validation_split=0.2, callbacks = [es, mc])
# Out:
# Epoch 1/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7300 - accuracy: 0.4864
# Epoch 1: val_accuracy improved from -inf to 0.46341, saving model to functional-first.h5
# 8/8 [==============================] - 21s 463ms/step - loss: 0.7300 - accuracy: 0.4864 - val_loss: 0.7139 - val_accuracy: 0.4634
# Epoch 2/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7103 - accuracy: 0.4783
# Epoch 2: val_accuracy improved from 0.46341 to 0.49322, saving model to functional-first.h5
# 8/8 [==============================] - 2s 227ms/step - loss: 0.7103 - accuracy: 0.4783 - val_loss: 0.7159 - val_accuracy: 0.4932
# Epoch 3/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7061 - accuracy: 0.5034
# Epoch 3: val_accuracy improved from 0.49322 to 0.49593, saving model to functional-first.h5
# 8/8 [==============================] - 2s 229ms/step - loss: 0.7061 - accuracy: 0.5034 - val_loss: 0.7150 - val_accuracy: 0.4959
# Epoch 4/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7069 - accuracy: 0.4803
# Epoch 4: val_accuracy did not improve from 0.49593
# 8/8 [==============================] - 2s 222ms/step - loss: 0.7069 - accuracy: 0.4803 - val_loss: 0.7037 - val_accuracy: 0.4499
# Epoch 5/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7045 - accuracy: 0.4953
# Epoch 5: val_accuracy did not improve from 0.49593
# 8/8 [==============================] - 2s 225ms/step - loss: 0.7045 - accuracy: 0.4953 - val_loss: 0.7042 - val_accuracy: 0.4932
# Epoch 6/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7018 - accuracy: 0.5088
# Epoch 6: val_accuracy improved from 0.49593 to 0.50949, saving model to functional-first.h5
# 8/8 [==============================] - 2s 229ms/step - loss: 0.7018 - accuracy: 0.5088 - val_loss: 0.7135 - val_accuracy: 0.5095
# Epoch 7/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6994 - accuracy: 0.5149
# Epoch 7: val_accuracy did not improve from 0.50949
# 8/8 [==============================] - 2s 224ms/step - loss: 0.6994 - accuracy: 0.5149 - val_loss: 0.7021 - val_accuracy: 0.4770
# Epoch 8/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6987 - accuracy: 0.5129
# Epoch 8: val_accuracy did not improve from 0.50949
# 8/8 [==============================] - 2s 224ms/step - loss: 0.6987 - accuracy: 0.5129 - val_loss: 0.7009 - val_accuracy: 0.4905
# Epoch 9/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6966 - accuracy: 0.5122
# Epoch 9: val_accuracy did not improve from 0.50949
# 8/8 [==============================] - 2s 224ms/step - loss: 0.6966 - accuracy: 0.5122 - val_loss: 0.7014 - val_accuracy: 0.4634
# Epoch 10/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6957 - accuracy: 0.5081
# Epoch 10: val_accuracy did not improve from 0.50949
# 8/8 [==============================] - 2s 224ms/step - loss: 0.6957 - accuracy: 0.5081 - val_loss: 0.7101 - val_accuracy: 0.5068
# Epoch 11/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6971 - accuracy: 0.5183
# Epoch 11: val_accuracy did not improve from 0.50949
# 8/8 [==============================] - 2s 224ms/step - loss: 0.6971 - accuracy: 0.5183 - val_loss: 0.6990 - val_accuracy: 0.5068
# Epoch 12/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.5095
# Epoch 12: val_accuracy did not improve from 0.50949
# 8/8 [==============================] - 2s 225ms/step - loss: 0.6940 - accuracy: 0.5095 - val_loss: 0.6967 - val_accuracy: 0.5068
# Epoch 13/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6941 - accuracy: 0.5176
# Epoch 13: val_accuracy did not improve from 0.50949
# 8/8 [==============================] - 2s 225ms/step - loss: 0.6941 - accuracy: 0.5176 - val_loss: 0.6976 - val_accuracy: 0.5014
# Epoch 14/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5156
# Epoch 14: val_accuracy improved from 0.50949 to 0.51491, saving model to functional-first.h5
# 8/8 [==============================] - 2s 232ms/step - loss: 0.6927 - accuracy: 0.5156 - val_loss: 0.6949 - val_accuracy: 0.5149
# Epoch 15/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6894 - accuracy: 0.5265
# Epoch 15: val_accuracy improved from 0.51491 to 0.53659, saving model to functional-first.h5
# 8/8 [==============================] - 2s 231ms/step - loss: 0.6894 - accuracy: 0.5265 - val_loss: 0.6901 - val_accuracy: 0.5366
# Epoch 16/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6899 - accuracy: 0.5400
# Epoch 16: val_accuracy improved from 0.53659 to 0.54743, saving model to functional-first.h5
# 8/8 [==============================] - 2s 233ms/step - loss: 0.6899 - accuracy: 0.5400 - val_loss: 0.6890 - val_accuracy: 0.5474
# Epoch 17/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6886 - accuracy: 0.5441
# Epoch 17: val_accuracy did not improve from 0.54743
# 8/8 [==============================] - 2s 226ms/step - loss: 0.6886 - accuracy: 0.5441 - val_loss: 0.7063 - val_accuracy: 0.5149
# Epoch 18/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6870 - accuracy: 0.5380
# Epoch 18: val_accuracy did not improve from 0.54743
# 8/8 [==============================] - 2s 227ms/step - loss: 0.6870 - accuracy: 0.5380 - val_loss: 0.6931 - val_accuracy: 0.5149
# Epoch 19/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6855 - accuracy: 0.5468
# Epoch 19: val_accuracy did not improve from 0.54743
# 8/8 [==============================] - 2s 226ms/step - loss: 0.6855 - accuracy: 0.5468 - val_loss: 0.6913 - val_accuracy: 0.5068
# Epoch 20/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6845 - accuracy: 0.5516
# Epoch 20: val_accuracy did not improve from 0.54743
# 8/8 [==============================] - 2s 226ms/step - loss: 0.6845 - accuracy: 0.5516 - val_loss: 0.6932 - val_accuracy: 0.5014
# Epoch 21/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6828 - accuracy: 0.5536
# Epoch 21: val_accuracy improved from 0.54743 to 0.57995, saving model to functional-first.h5
# 8/8 [==============================] - 2s 234ms/step - loss: 0.6828 - accuracy: 0.5536 - val_loss: 0.6836 - val_accuracy: 0.5799
# Epoch 22/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6816 - accuracy: 0.5590
# Epoch 22: val_accuracy did not improve from 0.57995
# 8/8 [==============================] - 2s 229ms/step - loss: 0.6816 - accuracy: 0.5590 - val_loss: 0.6878 - val_accuracy: 0.5095
# Epoch 23/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6878 - accuracy: 0.5366
# Epoch 23: val_accuracy improved from 0.57995 to 0.59350, saving model to functional-first.h5
# 8/8 [==============================] - 2s 233ms/step - loss: 0.6878 - accuracy: 0.5366 - val_loss: 0.6814 - val_accuracy: 0.5935
# Epoch 24/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6817 - accuracy: 0.5604
# Epoch 24: val_accuracy did not improve from 0.59350
# 8/8 [==============================] - 2s 230ms/step - loss: 0.6817 - accuracy: 0.5604 - val_loss: 0.6819 - val_accuracy: 0.5447
# Epoch 25/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6778 - accuracy: 0.5780
# Epoch 25: val_accuracy did not improve from 0.59350
# 8/8 [==============================] - 2s 230ms/step - loss: 0.6778 - accuracy: 0.5780 - val_loss: 0.6833 - val_accuracy: 0.5257
# Epoch 26/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6754 - accuracy: 0.5936
# Epoch 26: val_accuracy did not improve from 0.59350
# 8/8 [==============================] - 2s 229ms/step - loss: 0.6754 - accuracy: 0.5936 - val_loss: 0.6944 - val_accuracy: 0.5122
# Epoch 27/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6780 - accuracy: 0.5801
# Epoch 27: val_accuracy did not improve from 0.59350
# 8/8 [==============================] - 2s 229ms/step - loss: 0.6780 - accuracy: 0.5801 - val_loss: 0.6774 - val_accuracy: 0.5881
# Epoch 28/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6735 - accuracy: 0.5807
# Epoch 28: val_accuracy did not improve from 0.59350
# 8/8 [==============================] - 2s 231ms/step - loss: 0.6735 - accuracy: 0.5807 - val_loss: 0.6851 - val_accuracy: 0.5203
# Epoch 29/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6726 - accuracy: 0.5814
# Epoch 29: val_accuracy improved from 0.59350 to 0.60705, saving model to functional-first.h5
# 8/8 [==============================] - 2s 236ms/step - loss: 0.6726 - accuracy: 0.5814 - val_loss: 0.6729 - val_accuracy: 0.6070
# Epoch 30/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6699 - accuracy: 0.6018
# Epoch 30: val_accuracy did not improve from 0.60705
# 8/8 [==============================] - 2s 231ms/step - loss: 0.6699 - accuracy: 0.6018 - val_loss: 0.6915 - val_accuracy: 0.5312
# Epoch 31/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6734 - accuracy: 0.5848
# Epoch 31: val_accuracy improved from 0.60705 to 0.61247, saving model to functional-first.h5
# 8/8 [==============================] - 2s 236ms/step - loss: 0.6734 - accuracy: 0.5848 - val_loss: 0.6720 - val_accuracy: 0.6125
# Epoch 32/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6684 - accuracy: 0.6004
# Epoch 32: val_accuracy did not improve from 0.61247
# 8/8 [==============================] - 2s 230ms/step - loss: 0.6684 - accuracy: 0.6004 - val_loss: 0.6730 - val_accuracy: 0.5827
# Epoch 33/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6669 - accuracy: 0.5936
# Epoch 33: val_accuracy did not improve from 0.61247
# 8/8 [==============================] - 2s 229ms/step - loss: 0.6669 - accuracy: 0.5936 - val_loss: 0.6731 - val_accuracy: 0.5881
# Epoch 34/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6636 - accuracy: 0.6187
# Epoch 34: val_accuracy did not improve from 0.61247
# 8/8 [==============================] - 2s 237ms/step - loss: 0.6636 - accuracy: 0.6187 - val_loss: 0.6797 - val_accuracy: 0.5447
# Epoch 35/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6619 - accuracy: 0.6126
# Epoch 35: val_accuracy improved from 0.61247 to 0.63957, saving model to functional-first.h5
# 8/8 [==============================] - 2s 251ms/step - loss: 0.6619 - accuracy: 0.6126 - val_loss: 0.6651 - val_accuracy: 0.6396
# Epoch 36/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6701 - accuracy: 0.5834
# Epoch 36: val_accuracy did not improve from 0.63957
# 8/8 [==============================] - 2s 249ms/step - loss: 0.6701 - accuracy: 0.5834 - val_loss: 0.6755 - val_accuracy: 0.5881
# Epoch 37/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6592 - accuracy: 0.6201
# Epoch 37: val_accuracy did not improve from 0.63957
# 8/8 [==============================] - 2s 249ms/step - loss: 0.6592 - accuracy: 0.6201 - val_loss: 0.6685 - val_accuracy: 0.5962
# Epoch 38/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6668 - accuracy: 0.5923
# Epoch 38: val_accuracy did not improve from 0.63957
# 8/8 [==============================] - 2s 233ms/step - loss: 0.6668 - accuracy: 0.5923 - val_loss: 0.6683 - val_accuracy: 0.6098
# Epoch 39/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6560 - accuracy: 0.6411
# Epoch 39: val_accuracy did not improve from 0.63957
# 8/8 [==============================] - 2s 230ms/step - loss: 0.6560 - accuracy: 0.6411 - val_loss: 0.7269 - val_accuracy: 0.4959
# Epoch 40/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6683 - accuracy: 0.6113
# Epoch 40: val_accuracy did not improve from 0.63957
# 8/8 [==============================] - 2s 228ms/step - loss: 0.6683 - accuracy: 0.6113 - val_loss: 0.6597 - val_accuracy: 0.6233
# Epoch 41/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6528 - accuracy: 0.6309
# Epoch 41: val_accuracy did not improve from 0.63957
# 8/8 [==============================] - 2s 241ms/step - loss: 0.6528 - accuracy: 0.6309 - val_loss: 0.6582 - val_accuracy: 0.6341
# Epoch 42/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6465 - accuracy: 0.6391
# Epoch 42: val_accuracy did not improve from 0.63957
# 8/8 [==============================] - 2s 249ms/step - loss: 0.6465 - accuracy: 0.6391 - val_loss: 0.6642 - val_accuracy: 0.6233
# Epoch 43/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6481 - accuracy: 0.6221
# Epoch 43: val_accuracy did not improve from 0.63957
# 8/8 [==============================] - 2s 241ms/step - loss: 0.6481 - accuracy: 0.6221 - val_loss: 0.7210 - val_accuracy: 0.5474
# Epoch 44/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6787 - accuracy: 0.5936
# Epoch 44: val_accuracy did not improve from 0.63957
# 8/8 [==============================] - 2s 231ms/step - loss: 0.6787 - accuracy: 0.5936 - val_loss: 0.7231 - val_accuracy: 0.5312
# Epoch 45/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6539 - accuracy: 0.6336
# Epoch 45: val_accuracy improved from 0.63957 to 0.64770, saving model to functional-first.h5
# 8/8 [==============================] - 2s 237ms/step - loss: 0.6539 - accuracy: 0.6336 - val_loss: 0.6598 - val_accuracy: 0.6477
# Epoch 46/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6490 - accuracy: 0.6425
# Epoch 46: val_accuracy did not improve from 0.64770
# 8/8 [==============================] - 2s 232ms/step - loss: 0.6490 - accuracy: 0.6425 - val_loss: 0.6610 - val_accuracy: 0.5989
# Epoch 47/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6487 - accuracy: 0.6377
# Epoch 47: val_accuracy did not improve from 0.64770
# 8/8 [==============================] - 2s 237ms/step - loss: 0.6487 - accuracy: 0.6377 - val_loss: 0.6566 - val_accuracy: 0.6423
# Epoch 48/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6464 - accuracy: 0.6398
# Epoch 48: val_accuracy did not improve from 0.64770
# 8/8 [==============================] - 2s 234ms/step - loss: 0.6464 - accuracy: 0.6398 - val_loss: 0.6636 - val_accuracy: 0.6314
# Epoch 49/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6394 - accuracy: 0.6506
# Epoch 49: val_accuracy did not improve from 0.64770
# 8/8 [==============================] - 2s 236ms/step - loss: 0.6394 - accuracy: 0.6506 - val_loss: 0.6568 - val_accuracy: 0.6260
# Epoch 50/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6428 - accuracy: 0.6486
# Epoch 50: val_accuracy did not improve from 0.64770
# 8/8 [==============================] - 2s 237ms/step - loss: 0.6428 - accuracy: 0.6486 - val_loss: 0.6497 - val_accuracy: 0.6098
# Epoch 51/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6359 - accuracy: 0.6547
# Epoch 51: val_accuracy did not improve from 0.64770
# 8/8 [==============================] - 2s 234ms/step - loss: 0.6359 - accuracy: 0.6547 - val_loss: 0.6574 - val_accuracy: 0.6233
# Epoch 52/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6488 - accuracy: 0.6343
# Epoch 52: val_accuracy did not improve from 0.64770
# 8/8 [==============================] - 2s 240ms/step - loss: 0.6488 - accuracy: 0.6343 - val_loss: 0.6555 - val_accuracy: 0.6450
# Epoch 53/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6379 - accuracy: 0.6547
# Epoch 53: val_accuracy did not improve from 0.64770
# 8/8 [==============================] - 2s 240ms/step - loss: 0.6379 - accuracy: 0.6547 - val_loss: 0.6604 - val_accuracy: 0.6396
# Epoch 54/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6378 - accuracy: 0.6499
# Epoch 54: val_accuracy did not improve from 0.64770
# 8/8 [==============================] - 2s 237ms/step - loss: 0.6378 - accuracy: 0.6499 - val_loss: 0.6640 - val_accuracy: 0.6206
# Epoch 55/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6341 - accuracy: 0.6594
# Epoch 55: val_accuracy did not improve from 0.64770
# 8/8 [==============================] - 2s 236ms/step - loss: 0.6341 - accuracy: 0.6594 - val_loss: 0.7148 - val_accuracy: 0.5556

# %%
best_model = load_model(model_path)
best_model.evaluate([X_test, features_test], y_data_test)
# Out:
# 15/15 [==============================] - 1s 20ms/step - loss: 0.6732 - accuracy: 0.6074
# [0.6731593012809753, 0.6073752641677856]

# %%
import matplotlib.pyplot as plt

y_acc = hist.history["val_accuracy"]
y_vloss = hist.history["val_loss"]
xs = np.arange(1, len(y_acc) + 1)

plt.figure(figsize = (12,8))
plt.plot(xs, y_acc, label = "Validation Accuracy")
plt.plot(xs, y_vloss, label = "Validation loss")
plt.legend(), plt.grid(), plt.xlabel("Epoch"), plt.title("functional First"), plt.ylim([0.4,1])
plt.show()

# %%
from sklearn.metrics import confusion_matrix
y_train_pred=best_model.predict([X_test, features_test])
yhat=[]
for data in y_train_pred:
  if data>=0.5:
    yhat.append(1)
  else:
    yhat.append(0)
yhat

# %%
cf = confusion_matrix(y_data_test, yhat)
print(cf)
# Out:
# [[139  91]
#  [ 90 141]]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
p = precision_score(y_data_test, yhat)
print(p)
r = recall_score(y_data_test, yhat)
print(r)
f1 = f1_score(y_data_test, yhat)
print(f1)
# Out:
# 0.6077586206896551
# 0.6103896103896104
# 0.6090712742980562

# %% [markdown]
# # train_test dataset에 없는 다른 데이터로 모델 테스트

# %%
with open("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/test/test_mfcc_15세65세_aug전.pickle", "rb") as f:
    data = pickle.load(f)
length=[]
for i in range(len(data)):
    length.append(data[i].shape[1])
    
min_len=min(length)

result=[]
for i in range(len(data)):
    result.append(data[i][:,:min_len])
    
result_data_other=np.array(result)
result_data_other.shape
# Out:
# (520, 30, 901)

# %%
features_other = pd.read_csv("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/test/test_df_15세65세_aug전.csv")
features_other = features_other.iloc[:,[4,5,6,7]]
features_other
# Out:
#      man  respiratory_condition  fever_muscle_pain  COVID-19
# 0      1                      1                  0         0
# 1      1                      1                  0         0
# 2      1                      0                  0         0
# 3      1                      0                  0         0
# 4      1                      0                  0         0
# ..   ...                    ...                ...       ...
# 515    0                      0                  1         1
# 516    0                      0                  0         1
# 517    0                      0                  0         1
# 518    0                      0                  1         1
# 519    0                      0                  1         1
#
# [520 rows x 4 columns]

# %%
feature_test_data = features_other.iloc[:,:-1].values
y_test_data = features_other.iloc[:,-1].values

# %%
y_train_pred=model.predict([result_data_other, feature_test_data])
yhat_test=[]
for data in y_train_pred:
  if data>=0.5:
    yhat_test.append(1)
  else:
    yhat_test.append(0)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
p = precision_score(y_test_data, yhat_test)
print(p)
r = recall_score(y_test_data, yhat_test)
print(r)
f1 = f1_score(y_test_data, yhat_test)
print(f1)
# Out:
# 0.5176991150442478
# 0.9
# 0.6573033707865169

# %%
model.evaluate([result_data_other, feature_test_data], y_test_data)
# Out:
# 17/17 [==============================] - 0s 14ms/step - loss: 0.8224 - accuracy: 0.5308
# [0.8223668932914734, 0.5307692289352417]
