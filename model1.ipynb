# %%
# !pip install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.12)

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input, Concatenate, GlobalAveragePooling2D
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import pickle5 as pickle
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow as tf
seed=2022
tf.random.set_seed(seed)
np.random.seed(seed)

# %% [markdown]
# # mfcc

# %%
with open("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/mfcc/mfcc_lst_test.pickle", "rb") as f:
    data = pickle.load(f)
length=[]
for i in range(len(data)):
    length.append(data[i].shape[1])
    
min_len=min(length)

result=[]
for i in range(len(data)):
    result.append(data[i][:,:min_len])
    
result_data=np.array(result)
result_data.shape
# Out:
# (2076, 30, 901)

# %% [markdown]
# # codiv-19, feature

# %%
y = pd.read_csv("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/mfcc/Y_data_test.csv").iloc[:,0].values

# %%
features = pd.read_csv("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/csv파일/df_1565_test2.csv")
features = features.iloc[:,[4,5,6,7]]
feature_lst = []
for i in features.index:
    for _ in range(4):
        feature_lst.append(features.iloc[i,:].values)
features = pd.DataFrame(feature_lst)
features.shape
# Out:
# (2076, 4)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    result_data, features, stratify = features, test_size = 0.2
)

# %%
features_train = Y_train.iloc[:,:-1].values
y_data_train = Y_train.iloc[:,-1].values

# %%
features_test = Y_test.iloc[:,:-1].values
y_data_test = Y_test.iloc[:,-1].values

# %%
# 각 입력에 대한 형태를 명시
img_input = Input(shape = (30,901,1), name = "features_train")
form_input = Input(shape = (3,), name = "y_data_train")

# %%
# 이미지 입력
x_1 = Conv2D(128, (3,3), activation = "relu")(img_input)
x_1 = Conv2D(128, (3,3), activation = "relu")(x_1)
x_1 = MaxPooling2D(strides = 2)(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = Conv2D(64, (3,3), activation='relu')(x_1)
x_1 = Conv2D(64, (3,3), activation='relu')(x_1)
x_1 = Dropout(0.25)(x_1)
x_1 = GlobalAveragePooling2D()(x_1)

# 피쳐 입력
x_2 = Dense(32, input_dim = 3, activation  = "relu")(form_input)
# x_2 = Dense(32, activation = "relu")(form_input)

x = Concatenate()([x_1, x_2])
rate_pred = Dense(1, name = "covid", activation = "sigmoid")(x)

# %%
model = Model(inputs = [img_input, form_input],
              outputs = [rate_pred])

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  features_train (InputLayer)    [(None, 30, 901, 1)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 28, 899, 128  1280        ['features_train[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 26, 897, 128  147584      ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 13, 448, 128  0           ['conv2d_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 13, 448, 128  0           ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 11, 446, 64)  73792       ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 9, 444, 64)   36928       ['conv2d_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 9, 444, 64)   0           ['conv2d_3[0][0]']
#
#  y_data_train (InputLayer)      [(None, 3)]          0           []
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['dropout_1[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 32)           128         ['y_data_train[0][0]']
#
#  concatenate (Concatenate)      (None, 96)           0           ['global_average_pooling2d[0][0]'
#                                                                  , 'dense[0][0]']
#
#  covid (Dense)                  (None, 1)            97          ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 259,809
# Trainable params: 259,809
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = "adam",
              loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
model_path = "functional-first.h5"
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1, monitor = "val_accuracy")
es = EarlyStopping(patience=10, monitor = "val_accuracy")

# %%
hist = model.fit([X_train, features_train] , y_data_train,
                 epochs = 100, batch_size = 150,
                 validation_split=0.2, callbacks = [es, mc])
# Out:
# Epoch 1/100
# 9/9 [==============================] - ETA: 0s - loss: 0.8054 - accuracy: 0.4917
# Epoch 1: val_accuracy improved from -inf to 0.57229, saving model to functional-first.h5
# 9/9 [==============================] - 48s 2s/step - loss: 0.8054 - accuracy: 0.4917 - val_loss: 0.6827 - val_accuracy: 0.5723
# Epoch 2/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6886 - accuracy: 0.5550
# Epoch 2: val_accuracy did not improve from 0.57229
# 9/9 [==============================] - 10s 1s/step - loss: 0.6886 - accuracy: 0.5550 - val_loss: 0.6846 - val_accuracy: 0.5693
# Epoch 3/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6848 - accuracy: 0.5587
# Epoch 3: val_accuracy did not improve from 0.57229
# 9/9 [==============================] - 10s 1s/step - loss: 0.6848 - accuracy: 0.5587 - val_loss: 0.6746 - val_accuracy: 0.5723
# Epoch 4/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6828 - accuracy: 0.5572
# Epoch 4: val_accuracy did not improve from 0.57229
# 9/9 [==============================] - 10s 1s/step - loss: 0.6828 - accuracy: 0.5572 - val_loss: 0.6742 - val_accuracy: 0.5723
# Epoch 5/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6770 - accuracy: 0.5527
# Epoch 5: val_accuracy did not improve from 0.57229
# 9/9 [==============================] - 10s 1s/step - loss: 0.6770 - accuracy: 0.5527 - val_loss: 0.6678 - val_accuracy: 0.5723
# Epoch 6/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6740 - accuracy: 0.5527
# Epoch 6: val_accuracy did not improve from 0.57229
# 9/9 [==============================] - 10s 1s/step - loss: 0.6740 - accuracy: 0.5527 - val_loss: 0.6651 - val_accuracy: 0.5723
# Epoch 7/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6702 - accuracy: 0.5527
# Epoch 7: val_accuracy did not improve from 0.57229
# 9/9 [==============================] - 10s 1s/step - loss: 0.6702 - accuracy: 0.5527 - val_loss: 0.6610 - val_accuracy: 0.5723
# Epoch 8/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6669 - accuracy: 0.5527
# Epoch 8: val_accuracy did not improve from 0.57229
# 9/9 [==============================] - 10s 1s/step - loss: 0.6669 - accuracy: 0.5527 - val_loss: 0.6576 - val_accuracy: 0.5723
# Epoch 9/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6636 - accuracy: 0.5550
# Epoch 9: val_accuracy improved from 0.57229 to 0.57530, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6636 - accuracy: 0.5550 - val_loss: 0.6544 - val_accuracy: 0.5753
# Epoch 10/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6605 - accuracy: 0.5527
# Epoch 10: val_accuracy did not improve from 0.57530
# 9/9 [==============================] - 10s 1s/step - loss: 0.6605 - accuracy: 0.5527 - val_loss: 0.6494 - val_accuracy: 0.5723
# Epoch 11/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6570 - accuracy: 0.5678
# Epoch 11: val_accuracy improved from 0.57530 to 0.64458, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6570 - accuracy: 0.5678 - val_loss: 0.6491 - val_accuracy: 0.6446
# Epoch 12/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6540 - accuracy: 0.5715
# Epoch 12: val_accuracy did not improve from 0.64458
# 9/9 [==============================] - 10s 1s/step - loss: 0.6540 - accuracy: 0.5715 - val_loss: 0.6433 - val_accuracy: 0.5783
# Epoch 13/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6506 - accuracy: 0.5617
# Epoch 13: val_accuracy did not improve from 0.64458
# 9/9 [==============================] - 10s 1s/step - loss: 0.6506 - accuracy: 0.5617 - val_loss: 0.6400 - val_accuracy: 0.5964
# Epoch 14/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6475 - accuracy: 0.5956
# Epoch 14: val_accuracy improved from 0.64458 to 0.64759, saving model to functional-first.h5
# 9/9 [==============================] - 10s 1s/step - loss: 0.6475 - accuracy: 0.5956 - val_loss: 0.6382 - val_accuracy: 0.6476
# Epoch 15/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6447 - accuracy: 0.5881
# Epoch 15: val_accuracy did not improve from 0.64759
# 9/9 [==============================] - 10s 1s/step - loss: 0.6447 - accuracy: 0.5881 - val_loss: 0.6341 - val_accuracy: 0.6205
# Epoch 16/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6422 - accuracy: 0.6212
# Epoch 16: val_accuracy did not improve from 0.64759
# 9/9 [==============================] - 10s 1s/step - loss: 0.6422 - accuracy: 0.6212 - val_loss: 0.6316 - val_accuracy: 0.6446
# Epoch 17/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6401 - accuracy: 0.6310
# Epoch 17: val_accuracy did not improve from 0.64759
# 9/9 [==============================] - 10s 1s/step - loss: 0.6401 - accuracy: 0.6310 - val_loss: 0.6294 - val_accuracy: 0.6325
# Epoch 18/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6388 - accuracy: 0.5994
# Epoch 18: val_accuracy did not improve from 0.64759
# 9/9 [==============================] - 10s 1s/step - loss: 0.6388 - accuracy: 0.5994 - val_loss: 0.6289 - val_accuracy: 0.6265
# Epoch 19/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6364 - accuracy: 0.6265
# Epoch 19: val_accuracy did not improve from 0.64759
# 9/9 [==============================] - 10s 1s/step - loss: 0.6364 - accuracy: 0.6265 - val_loss: 0.6264 - val_accuracy: 0.6265
# Epoch 20/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6342 - accuracy: 0.6355
# Epoch 20: val_accuracy did not improve from 0.64759
# 9/9 [==============================] - 10s 1s/step - loss: 0.6342 - accuracy: 0.6355 - val_loss: 0.6233 - val_accuracy: 0.6355
# Epoch 21/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6336 - accuracy: 0.6280
# Epoch 21: val_accuracy did not improve from 0.64759
# 9/9 [==============================] - 10s 1s/step - loss: 0.6336 - accuracy: 0.6280 - val_loss: 0.6240 - val_accuracy: 0.6265
# Epoch 22/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6317 - accuracy: 0.6288
# Epoch 22: val_accuracy did not improve from 0.64759
# 9/9 [==============================] - 10s 1s/step - loss: 0.6317 - accuracy: 0.6288 - val_loss: 0.6203 - val_accuracy: 0.6446
# Epoch 23/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6309 - accuracy: 0.6318
# Epoch 23: val_accuracy did not improve from 0.64759
# 9/9 [==============================] - 10s 1s/step - loss: 0.6309 - accuracy: 0.6318 - val_loss: 0.6216 - val_accuracy: 0.6265
# Epoch 24/100
# 9/9 [==============================] - ETA: 0s - loss: 0.6298 - accuracy: 0.6348
# Epoch 24: val_accuracy did not improve from 0.64759
# 9/9 [==============================] - 10s 1s/step - loss: 0.6298 - accuracy: 0.6348 - val_loss: 0.6186 - val_accuracy: 0.6416

# %%
best_model = load_model(model_path)
best_model.evaluate([X_test, features_test], y_data_test)
# Out:
# 13/13 [==============================] - 1s 62ms/step - loss: 0.6427 - accuracy: 0.6274
# [0.6426677703857422, 0.6274038553237915]

# %%
import matplotlib.pyplot as plt

y_acc = hist.history["val_accuracy"]
y_vloss = hist.history["val_loss"]
xs = np.arange(1, len(y_acc) + 1)

plt.figure(figsize = (12,8))
plt.plot(xs, y_acc, label = "Validation Accuracy")
plt.plot(xs, y_vloss, label = "Validation loss")
plt.legend(), plt.grid(), plt.xlabel("Epoch"), plt.title("functional First"), plt.ylim([0.4,1])
plt.show()

# %%
from sklearn.metrics import confusion_matrix
y_train_pred=best_model.predict([X_test, features_test])
yhat=[]
for data in y_train_pred:
  if data>=0.5:
    yhat.append(1)
  else:
    yhat.append(0)
yhat

# %%
cf = confusion_matrix(y_data_test, yhat)
print(cf)
# Out:
# [[146  38]
#  [117 115]]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
p = precision_score(y_data_test, yhat)
print(p)
r = recall_score(y_data_test, yhat)
print(r)
f1 = f1_score(y_data_test, yhat)
print(f1)
# Out:
# 0.7516339869281046
# 0.4956896551724138
# 0.5974025974025975

# %% [markdown]
# # train_test dataset에 없는 다른 데이터로 모델 테스트

# %%
with open("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/test/fffff.pickle", "rb") as f:
    data = pickle.load(f)
length=[]
for i in range(len(data)):
    length.append(data[i].shape[1])
    
min_len=min(length)

result=[]
for i in range(len(data)):
    result.append(data[i][:,:min_len])
    
result_data_other=np.array(result)
result_data_other.shape
# Out:
# (520, 30, 901)

# %%
features_other = pd.read_csv("/content/drive/MyDrive/멀캠_2nd_semiproject/데이터/test/test_df_15세65세_aug전.csv")
features_other = features_other.iloc[:,[4,5,6,7]]
features_other
# Out:
#      man  respiratory_condition  fever_muscle_pain  COVID-19
# 0      1                      1                  0         0
# 1      1                      1                  0         0
# 2      1                      0                  0         0
# 3      1                      0                  0         0
# 4      1                      0                  0         0
# ..   ...                    ...                ...       ...
# 515    0                      0                  1         1
# 516    0                      0                  0         1
# 517    0                      0                  0         1
# 518    0                      0                  1         1
# 519    0                      0                  1         1
#
# [520 rows x 4 columns]

# %%
feature_test_data = features_other.iloc[:,:-1].values
y_test_data = features_other.iloc[:,-1].values

# %%
y_train_pred=model.predict([result_data_other, feature_test_data])
yhat_test=[]
for data in y_train_pred:
  if data>=0.5:
    yhat_test.append(1)
  else:
    yhat_test.append(0)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
p = precision_score(y_test_data, yhat_test)
print(p)
r = recall_score(y_test_data, yhat_test)
print(r)
f1 = f1_score(y_test_data, yhat_test)
print(f1)
# Out:
# 0.5930232558139535
# 0.5884615384615385
# 0.5907335907335908

# %%
model.evaluate([result_data_other, feature_test_data], y_test_data)
# Out:
# 17/17 [==============================] - 1s 60ms/step - loss: 0.6768 - accuracy: 0.5923
# [0.6767964959144592, 0.5923076868057251]
